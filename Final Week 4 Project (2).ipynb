# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Julie DeCuire**
#
# Data Scientist

# %% [markdown]
# *I am interested in Data Science in order to deeply understand health trends*

# %% [markdown]
# ### data should calculate health trends

# %%
(1+1)
# Out:
# 2

# %% [markdown]
# - one
# - two
# - three
#
# | Date | Time | Views |
# | --- | --- | --- |
# | August | 3:55 pm | 7 |
# |September| 3:46 pm | 3 |
#
# > blockquotes **are** *very* handy
